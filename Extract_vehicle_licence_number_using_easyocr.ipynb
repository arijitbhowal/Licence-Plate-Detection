# %% [markdown]
# #  Importing required libraries

# %%
import torch
import cv2
import time
import re
import numpy as np
import easyocr

# %% [markdown]
# # Initiating easyocr

# %%
##### DEFINING GLOBAL VARIABLE
EASY_OCR = easyocr.Reader(['en']) 
OCR_TH = 0.2
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %% [markdown]
# #  Function to run detection

# %%
def detectx (frame, model):
    frame = [frame]
    print(f"[INFO] Detecting. . . ")
    results = model(frame)
    labels, cordinates = results.xyxyn[0][:, -1], results.xyxyn[0][:, :-1]

    return labels, cordinates

# %% [markdown]
# # To plot the BBox and results

# %%
def plot_boxes(results, frame,classes):

    """
    --> This function takes results, frame and classes
    --> results: contains labels and coordinates predicted by model on the given frame
    --> classes: contains the strting labels

    """
    labels, cord = results
    n = len(labels)
    x_shape, y_shape = frame.shape[1], frame.shape[0]

    print(f"[INFO] Total {n} detections. . . ")
    print(f"[INFO] Looping through all detections. . . ")


    ### looping through the detections
    for i in range(n):
        row = cord[i]
        if row[4] >= 0.55: ### threshold value for detection. We are discarding everything below this value
            print(f"[INFO] Extracting BBox coordinates. . . ")
            x1, y1, x2, y2 = int(row[0]*x_shape), int(row[1]*y_shape), int(row[2]*x_shape), int(row[3]*y_shape) ## BBOx coordniates
            text_d = classes[int(labels[i])]
            coords = [x1,y1,x2,y2]

            plate_num = recognize_plate_easyocr(img = frame, coords= coords, reader= EASY_OCR, region_threshold= OCR_TH)

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) ## BBox
            cv2.rectangle(frame, (x1, y1-20), (x2, y1), (0, 255,0), -1) ## for text label background
            cv2.putText(frame, f"{plate_num}", (x1, y1), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(255,255,255), 2)

    return frame

# %% [markdown]
# # Function to recognize license plate

# %%
# function to recognize license plate numbers using Tesseract OCR
def recognize_plate_easyocr(img, coords,reader,region_threshold):
    # separate coordinates from box
    xmin, ymin, xmax, ymax = coords
    # get the subimage that makes up the bounded region and take an additional 5 pixels on each side
    # nplate = img[int(ymin)-5:int(ymax)+5, int(xmin)-5:int(xmax)+5]
    nplate = img[int(ymin):int(ymax), int(xmin):int(xmax)] ### cropping the number plate from the whole image

    ocr_result = reader.readtext(nplate)

    text = filter_text(region=nplate, ocr_result=ocr_result, region_threshold= region_threshold)

    if len(text) ==1:
        text = text[0].upper()
    return text

### to filter out wrong detections 

def filter_text(region, ocr_result, region_threshold):
    rectangle_size = region.shape[0]*region.shape[1]
    
    plate = [] 
    print(ocr_result)
    for result in ocr_result:
        length = np.sum(np.subtract(result[0][1], result[0][0]))
        height = np.sum(np.subtract(result[0][2], result[0][1]))
        
        if length*height / rectangle_size > region_threshold:
            plate.append(result[1])
    return plate

# %% [markdown]
# # Main function

# %%
def main(img_path=None, vid_path=None,vid_out = None):

    print(f"[INFO] Loading model... ")
    ## loading the custom trained model
    # model =  torch.hub.load('ultralytics/yolov5', 'custom', path='last.pt',force_reload=True) ## if you want to download the git repo and then run the detection
    model = torch.hub.load('yolov5', 'custom', source='local', path='yolov5/runs/train/yolov5s_results/weights/best.pt')

    classes = model.names ### class names in string format




    # For detection on image
    if img_path != None:
        print(f"[INFO] Working with image: {img_path}")
        img_out_name = f"./output/result_{img_path.split('/')[-1]}"

        frame = cv2.imread(img_path) ### reading the image
        frame = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        
        results = detectx(frame, model = model) ### DETECTION HAPPENING HERE    

        frame = cv2.cvtColor(frame,cv2.COLOR_RGB2BGR)

        frame = plot_boxes(results, frame,classes = classes)
        

        cv2.namedWindow("img_only", cv2.WINDOW_NORMAL) ## creating a free windown to show the result

        while True:
            # frame = cv2.cvtColor(frame,cv2.COLOR_RGB2BGR)

            cv2.imshow("img_only", frame)

            if cv2.waitKey(5) & 0xFF == ord('q'):
                print(f"[INFO] Exiting. . . ")

                cv2.imwrite(f"{img_out_name}",frame) ## if you want to save he output result.

                break

    # For detection on video
    elif vid_path !=None:
        print(f"[INFO] Working with video: {vid_path}")

        ## reading the video
        cap = cv2.VideoCapture(vid_path)

        # Placeholder for the out variable
        out = None

        if vid_out:  # creating the video writer if video output path is given
            width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))
            codec = cv2.VideoWriter_fourcc(*'mp4v')  # or your desired codec
            out = cv2.VideoWriter(vid_out, codec, fps, (width, height))

        # assert cap.isOpened()
        frame_no = 1

        cv2.namedWindow("vid_out", cv2.WINDOW_NORMAL)
        while True:
            # start_time = time.time()
            ret, frame = cap.read()
            if ret  and frame_no %1 == 0:
                print(f"[INFO] Working with frame {frame_no} ")

                frame = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
                results = detectx(frame, model = model)
                frame = cv2.cvtColor(frame,cv2.COLOR_RGB2BGR)


                frame = plot_boxes(results, frame,classes = classes)
                
                cv2.imshow("vid_out", frame)
                if vid_out:
                    print(f"[INFO] Saving output video. . . ")
                    out.write(frame)

                if cv2.waitKey(5) & 0xFF == ord('q'):
                    break
                frame_no += 1
        
        # Release the VideoWriter if it was created
        if out is not None:
            print(f"[INFO] Cleaning up. . . ")
            out.release()
        
        ## closing all windows
        cv2.destroyAllWindows()

# %%
main(img_path="img1.jpeg") #for image
# Out:
# [INFO] Loading model...
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Requirement already satisfied: gitpython in c:\users\ariji\anaconda3\lib\site-packages (3.1.38)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ariji\anaconda3\lib\site-packages (from gitpython) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ariji\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython) (5.0.1)
#
# requirements: 1 package updated per C:\Users\ariji\Desktop\ANPR\yolov5\requirements.txt
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  v7.0-72-g064365d Python-3.11.4 torch-2.1.0+cpu CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7246518 parameters, 0 gradients
# Adding AutoShape...
# [INFO] Working with image: img1.jpeg
# [INFO] Detecting. . .
# [INFO] Total 1 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[19, 7], [177, 7], [177, 40], [19, 40]], 'UP16AJL567', 0.8161174996969421)]
# [INFO] Exiting. . .

# %%
main(vid_path='vid1.mp4') #for video
# Out:
# [INFO] Loading model...
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Requirement already satisfied: gitpython in c:\users\ariji\anaconda3\lib\site-packages (3.1.38)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ariji\anaconda3\lib\site-packages (from gitpython) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ariji\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython) (5.0.1)
#
# requirements: 1 package updated per C:\Users\ariji\Desktop\ANPR\yolov5\requirements.txt
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  v7.0-72-g064365d Python-3.11.4 torch-2.1.0+cpu CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7246518 parameters, 0 gradients
# Adding AutoShape...
# [INFO] Working with video: vid1.mp4
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[0, 3], [72, 3], [72, 21], [0, 21]], '4Ao8 BZM', 0.2433444130387395)]
# [INFO] Extracting BBox coordinates. . .
# [([[4, 0], [124, 0], [124, 32], [4, 32]], 'L456 LhC', 0.4605901121061897)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[0, 3], [82, 3], [82, 23], [0, 23]], 'MAo8 BZM ', 0.09451382465690311)]
# [INFO] Extracting BBox coordinates. . .
# [([[6, 0], [126, 0], [126, 32], [6, 32]], 'L456 LhC', 0.44600754602161874)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[1, 3],
]
# [INFO] Extracting BBox coordinates. . .
# [([[19, 3], [76, 3], [76, 23], [19, 23]], 'ARRIVA', 0.6631725481670284)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 0], [93, 0], [93, 30], [10, 30]], 'LPIS VL', 0.31086076037870586)]
# [INFO] Extracting BBox coordinates. . .
# [([[17, 3], [74, 3], [74, 23], [17, 23]], 'ARRIVA', 0.8660961523587501)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 0], [94, 0], [94, 30], [10, 30]], 'LPIS VL', 0.2364642418232878)]
# [INFO] Extracting BBox coordinates. . .
# [([[17, 3], [74, 3], [74, 23], [17, 23]], 'ARRIVA', 0.8888429693303865)]
# [INFO] Extracting BBox coordinates. . .
# [([[5, 0], [79, 0], [79, 11], [5, 11]], 'U FRiivi', 0.002397229859741674)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 0], [96, 0], [96, 30], [10, 30]], 'LPIS VL', 0.2751084187064932)]
# [INFO] Extracting BBox coordinates. . .
# [([[19, 3], [75, 3], [75, 23], [19, 23]], 'ARRIVA', 0.647889783298005)]
# [INFO] Extracting BBox coordinates. . .
# [([[5, 0], [79, 0], [79, 13], [5, 13]], 'YARRIva', 0.0295555204146268)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 0], [98, 0], [98, 30], [10, 30]], 'LPIS L', 0.16930668244215583)]
# [INFO] Extracting BBox coordinates. . .
# [([[0, 0], [75, 0], [75, 24], [0, 24]], '2 ARRIVI', 0.9693625533530292)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 2], [99, 2], [99, 31], [10, 31]], 'LPISWD', 0.28961283082798656)]
# [INFO] Extracting BBox coordinates. . .
# [([[0, 0], [75, 0], [75, 24], [0, 24]], '2 ARRIVI', 0.6277135409491306)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 0], [100, 0], [100, 31], [10, 31]], 'LPIS VVD', 0.2112132224261058)]
# [INFO] Extracting BBox coordinates. . .
# [([[0, 0], [75, 0], [75, 24], [0, 24]], '2 ARRIVI', 0.9543368803771692)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 2], [102, 2], [102, 31], [10, 31]], 'LPIS VD', 0.26279065009374125)]
# [INFO] Extracting BBox coordinates. . .
# [([[0, 0], [77, 0], [77, 24], [0, 24]], '2 ARRIVA', 0.8723407243751822)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 0], [106, 0], [106, 30], [12, 30]], 'Leis VD', 0.2601386731802913)]
# [INFO] Extracting BBox coordinates. . .
# [([[0, 0], [78, 0], [78, 24], [0, 24]], '2 ARRIVA', 0.8387668989344075)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 0], [107, 0], [107, 30], [12, 30]], 'LPIs VD', 0.18711861995612702)]
# [INFO] Extracting BBox coordinates. . .
# [([[15, 0], [77, 0], [77, 25], [15, 25]], 'ARRIVA', 0.9130359956835288)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 0], [109, 0], [109, 31], [12, 31]], 'LeIs D', 0.2681348002245788)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 0], [110, 0], [110, 31], [12, 31]], 'LeIS DL', 0.11680868725728893)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 0], [112, 0], [112, 31], [12, 31]], 'L?i5 VDI', 0.19732296037502708)]
# [INFO] Extracting BBox coordinates. . .
# [([[23, 13], [47, 13], [47, 26], [23, 26]], 'J60', 0.4547834599269435)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 0], [112, 0], [112, 31], [12, 31]], 'LeIS DL', 0.23024533417879905)]
# [INFO] Extracting BBox coordinates. . .
# [([[22, 0], [78, 0], [78, 8], [22, 8]], 'Tua', 0.00047021646192410495), ([[23, 15], [45, 15], [45, 27], [23, 27]], '16O', 0.3243688727137755)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 2], [115, 2], [115, 32], [10, 32]], 'LPIS DI', 0.3454902993433754)]
# [INFO] Extracting BBox coordinates. . .
# [([[1, 0], [78, 0], [78, 11], [1, 11]], 'RU Ani Vi', 0.00028957378024859214), ([[23, 15], [45, 15], [45, 28], [23, 28]], '160r', 0.4005472958087921)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 2], [117, 2], [117, 32], [10, 32]], 'LPIS DV', 0.2685419205281052)]
# [INFO] Extracting BBox coordinates. . .
# [([[1, 0], [78, 0], [78, 11], [1, 11]], 'Cl tamni Vi', 0.0004429813672123923), ([[17, 15], [47, 15], [47, 29], [17, 29]], 'J6o', 0.23259200677678527)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 0], [121, 0], [121, 32], [12, 32]], 'LPIS VDV', 0.5248525130794177)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 0], [123, 0], [123, 32], [12, 32]], 'LPIS NDV', 0.2762151089261855)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 0], [125, 0], [125, 30], [10, 30]], 'LPIS DV', 0.2584109710490912)]
# [INFO] Detecting. . .
# [INFO] Total 3 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 0], [127, 0], [127, 30], [10, 30]], 'LPIS DV', 0.39539140535257733)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 0], [126, 0], [126, 30], [10, 30]], 'LPIS DV', 0.5943469343361623)]
# [INFO] Extracting BBox coordinates. . .
# [([[9, 7], [68, 7], [68, 23], [9, 23]], 'LJ6O AX', 0.22352393670909243)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 2], [128, 2], [128, 34], [12, 34]], 'LPIS DV', 0.3159049575325537)]
# [INFO] Extracting BBox coordinates. . .
# [([[7, 5], [65, 5], [65, 21], [7, 21]], 'LJbouX', 0.618086013169957)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 2], [129, 2], [129, 34], [12, 34]], 'LPIS DV', 0.3748832041067184)]
# [INFO] Extracting BBox coordinates. . .
# [([[7, 5], [63, 5], [63, 21], [7, 21]], 'LJeol', 0.2766735830913965)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 4], [126, 4], [126, 36], [12, 36]], 'LPIS DV', 0.7434226547174635)]
# [INFO] Extracting BBox coordinates. . .
# [([[9, 5], [49, 5], [49, 21], [9, 21]], 'LJbq', 0.2938011884689331)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 4], [123, 4], [123, 36], [12, 36]], 'LPIS NDI', 0.18593193657942417)]
# [INFO] Extracting BBox coordinates. . .
# [([[19, 7], [60, 7], [60, 22], [19, 22]], 'Jeoa', 0.42025551199913025)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 4], [118, 4], [118, 36], [12, 36]], 'LPIS D', 0.4940470989454642)]
# [INFO] Extracting BBox coordinates. . .
# [([[19, 7], [47, 7], [47, 21], [19, 21]], 'J60', 0.5111632147503326)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 2], [114, 2], [114, 34], [12, 34]], 'LPIS WD', 0.3041174707648448)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 2], [107, 2], [107, 34], [12, 34]], 'LPISNL', 0.18353976451674603)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[10, 0], [102, 0], [102, 32], [10, 32]], 'LPIS VL', 0.17349192515219006)]
# [INFO] Extracting BBox coordinates. . .
# [([[5, 5], [45, 5], [45, 20], [5, 20]], 'LJso', 0.24039287388143532)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[11, 0], [79, 0], [79, 34], [11, 34]], 'LPl5 ', 0.17388612855565266)]
# [INFO] Extracting BBox coordinates. . .
# [([[7, 5], [47, 5], [47, 20], [7, 20]], 'Ljbo)', 0.17980078327425517)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[11, 0], [79, 0], [79, 34], [11, 34]], 'Lel5 ', 0.19029283245952006)]
# [INFO] Extracting BBox coordinates. . .
# []
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[12, 2], [78, 2], [78, 34], [12, 34]], 'LeIs', 0.22783656418323517)]
# [INFO] Extracting BBox coordinates. . .
# []
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[11, 1], [79, 1], [79, 36], [11, 36]], 'Lel5', 0.11335355043411255)]
# [INFO] Extracting BBox coordinates. . .
# []
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# []
# [INFO] Extracting BBox coordinates. . .
# [([[12, 4], [80, 4], [80, 36], [12, 36]], 'Leis', 0.3276195824146271)]
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[14, 4], [79, 4], [79, 36], [14, 36]], 'Lpis', 0.1451875865459442)]
# [INFO] Extracting BBox coordinates. . .
# []
# [INFO] Detecting. . .
# [INFO] Total 2 detections. . .
# [INFO] Looping through all detections. . .
# [INFO] Extracting BBox coordinates. . .
# [([[14, 4], [73, 4], [73, 36], [14, 36]], 'Lels', 0.36583083868026733)]
# [INFO] Extracting BBox coordinates. . .
# []
